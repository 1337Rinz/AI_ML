# %% [markdown]
# <a href="https://colab.research.google.com/github/1337Rinz/AI_ML/blob/main/BOOST_RES_SeedVR2_comfyUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -U diffusers
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 44.4 MB/s eta 0:00:00
# ...
#   Attempting uninstall: diffusers
#     Found existing installation: diffusers 0.35.1
#     Uninstalling diffusers-0.35.1:
#       Successfully uninstalled diffusers-0.35.1
# ...

# %% [markdown]
# ## Local Inference on GPU
# Model page: https://huggingface.co/numz/SeedVR2_comfyUI
#
# ⚠️ If the generated code snippets do not work, please open an issue on either the [model repo](https://huggingface.co/numz/SeedVR2_comfyUI)
# 			and/or on [huggingface.js](https://github.com/huggingface/huggingface.js/blob/main/packages/tasks/src/model-libraries-snippets.ts) 🙏

# %%
from diffusers import DiffusionPipeline

pipe = DiffusionPipeline.from_pretrained("numz/SeedVR2_comfyUI")

prompt = "Astronaut in a jungle, cold color palette, muted colors, detailed, 8k"
image = pipe(prompt).images[0]
